# %% [markdown]
# ## Lists:
# - List are ordered sequence of mixed data type
# - Lists are writen in comma separatess elements within square bracket

# %% [markdown]
# ###### lists are:
# - interger
# - float
# - string
# - combinational
# - list--> nested lits

# %%
cust_new = ["python",21.3,'AI',True,"hong kong123"]

# %%
type(cust_new)
print(cust_new)
# Out:
# ['python', 21.3, 'AI', True, 'hong kong123']

# %%
cust_new_info = ("python",21.3,'AI',True,"hong kong123")

type(cust_new_info)
# Out:
# tuple

# %%
print(cust_new_info)
# Out:
# ('python', 21.3, 'AI', True, 'hong kong123')

# %%
list1 = ['new Delhu',123,"Mathura"]
print(list1)
# Out:
# ['new Delhu', 123, 'Mathura']

# %%
print(type(list1))
print(len(list1))
# Out:
# <class 'list'>
# 3

# %%
## nesgted list 
list2 = ["rahull" ,123,"new yourk",34.33,[123,"rohan"]]
print(list2)
print(type(list2))
# Out:
# ['rahull', 123, 'new yourk', 34.33, [123, 'rohan']]
# <class 'list'>

# %%
list2
# Out:
# ['rahull', 123, 'new yourk', 34.33, [123, 'rohan']]

# %%
list2[-1][0]
# Out:
# 123

# %%
list2[4][1]
# Out:
# 'rohan'

# %%
list2[2]
# Out:
# 'new yourk'

# %%
len(list2)
# Out:
# 5

# %%
list2[-1][-2]
# Out:
# 123

# %%
### list concatination
list3 = list1 + list2
print(list3)
# Out:
# ['new Delhu', 123, 'Mathura', 'rahull', 123, 'new yourk', 34.33, [123, 'rohan']]

# %%
## Add two element on existing list
list4 = list2 + [12,34,"new list"]
list4
# Out:
# ['rahull', 123, 'new yourk', 34.33, [123, 'rohan'], 12, 34, 'new list']

# %%
# Memebership in list and tuple 

tuple1 = (12,2,3,4)
print(1 in tuple1)
# Out:
# False

# %%
print(12 in tuple1)
# Out:
# True

# %%
new_list = [12,34,55,6,78,90]
print(34 in new_list)
print(100 in new_list)
# Out:
# True
# False

# %% [markdown]
# ### Mutable and Immutable Objects in Python ######

# %%
list_1 = ["math","chemistry","physics","biology"]
list_1
# Out:
# ['math', 'chemistry', 'physics', 'biology']

# %%
list_1[2] ="computer science"

# %%
list_1
# Out:
# ['math', 'chemistry', 'computer science', 'biology']

# %%
list_1.append("data science")
list_1
# Out:
# ['math', 'chemistry', 'computer science', 'biology', 'data science']

# %%
list_1.insert(0,"sql")
list_1
# Out:
# ['sql', 'math', 'chemistry', 'computer science', 'biology', 'data science']

# %%
list_1.append("biology")

# %%
list_1.remove("biology")

# %%
list_1
# Out:
# ['sql', 'math', 'chemistry', 'computer science', 'data science']

# %%
list_1.pop(1)
# Out:
# 'math'

# %%
list_1
# Out:
# ['sql', 'chemistry', 'computer science', 'data science']

# %%
# extend() --> its extends the list 
list_2 = ["math","chemistry","physics","biology", 1,2,3,4]
list_2.extend([2,"cse"])
list_2
# Out:
# ['math', 'chemistry', 'physics', 'biology', 1, 2, 3, 4, 2, 'cse']

# %%
del list_2[2]

# %%
l1 = [1,4,2,9,5,8,6,0]

# %%
l1.sort()
l1
# Out:
# [0, 1, 2, 4, 5, 6, 8, 9]

# %%
A = ["Banana","Orange","Strawberry","Mango"]
B = A.sort()
print(A)
print(B)
# Out:
# ['Banana', 'Mango', 'Orange', 'Strawberry']
# None

# %%
B = sorted(A)
print(B)
# Out:
# ['Banana', 'Mango', 'Orange', 'Strawberry']

# %%
# Shallow Copy

A1 = ["Banana","Orange","Strawberry","Mango"]
B1 = A1
print(B1)
print(A1)
# Out:
# ['Banana', 'Orange', 'Strawberry', 'Mango']
# ['Banana', 'Orange', 'Strawberry', 'Mango']

# %%
A1.pop()
# Out:
# 'Mango'

# %%
A1
# Out:
# ['Banana', 'Orange', 'Strawberry']

# %%
B1
# Out:
# ['Banana', 'Orange', 'Strawberry']
