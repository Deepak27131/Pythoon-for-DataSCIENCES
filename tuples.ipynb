# %% [markdown]
# ### Tuples
#
# - Tuple is order of mutiple sequence of charater
# - tupple are assign in comma separate value like()

# %%
t1 = (1,2,3,"hello")
t1
# Out:
# (1, 2, 3, 'hello')

# %%
type(t1)
# Out:
# tuple

# %%
t2 = (1,2,3,4,"hello",(5,6,7))
type(t2)
# Out:
# tuple

# %%
t2
# Out:
# (1, 2, 3, 4, 'hello', (5, 6, 7))

# %%
len
# Out:
# 6

# %%
t4 = ("rohan", "kumar", 123, 45.67, [1,2,8])
t4
# Out:
# ('rohan', 'kumar', 123, 45.67, [1, 2, 8])

# %%
var = t4[-1]
print(var)
# Out:
# [1, 2, 8]

# %%
type(var)
# Out:
# list

# %%
type(t4)
# Out:
# tuple

# %%
t4[-1][2]
# Out:
# 8

# %% [markdown]
# #### tuple can define in various wAY

# %%
t1 = 1,2,3,4,5,6
print(type(t1))
t1
# Out:
# <class 'tuple'>
# (1, 2, 3, 4, 5, 6)

# %%
t1 = 1.2,2.3
print(type(t1))
# Out:
# <class 'tuple'>

# %%
t1 = 1.2
print(type(t1))
# Out:
# <class 'float'>

# %%
t1 = 1,
t1
# Out:
# (1,)

# %%
type(t1)
# Out:
# tuple

# %%
t2 = (1)
print(type(t2))
t2
# Out:
# <class 'int'>
# 1

# %%
t2 = (1,)
print(type(t2))
t2
# Out:
# <class 'tuple'>
# (1,)

# %%
len(t2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 len(t2)
#
# TypeError: object of type 'int' has no len()

# %%
t2 = (12,2,3,'miaobo')
t2
# Out:
# (12, 2, 3, 'miaobo')

# %% [markdown]
# ### Indexing in tuple

# %%
t = ("Mumbai", 10, "Jaipur",12,"up",14)
t[2]
# Out:
# 'Jaipur'

# %%
t[2:]
# Out:
# ('Jaipur', 12, 'up', 14)

# %%
t[-1:]
# Out:
# (14,)

# %%
t[:-1]
# Out:
# ('Mumbai', 10, 'Jaipur', 12, 'up')

# %%
t = ("hello world",12,2,"python",45)
t1 = " ".join(str(x) for x in reversed(t))
print(t1)
# Out:
# 45 python 2 12 hello world

# %%
reve = t[::-1]
reve
# Out:
# (14, 'up', 12, 'Jaipur', 10, 'Mumbai')

# %%
str1 = "hello world"
str1_rev = "".join(reversed(str1))

# %%
str1_rev
# Out:
# 'dlrow olleh'

# %%
str1 = " hello word"
str1[6:]
# Out:
# ' word'

# %%
str1[:6]
# Out:
# ' hello'

# %%
## concatenation of tuples
t1 = (1,2,3)
t2 = ("hello","world")
t3 = t1 + t2

# %%
t3
# Out:
# (1, 2, 3, 'hello', 'world')

# %%
t = (1,2,3,4,5,67,4)
sum(t)
# Out:
# 86

# %%
max(t)
# Out:
# 67

# %%
min(t)
# Out:
# 1

# %%
t1 = (1,2,3,"hello")
sum(t1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 2
#       1 t1 = (1,2,3,"hello")
# ----> 2 sum(t1)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
## immutable nature of tuples
t1 = (1,2,3,4,5)
t1[2] = 10
# --- IGNORE ---
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 3
#       1 ## immutable nature of tuples
#       2 t1 = (1,2,3,4,5)
# ----> 3 t1[2] = 10
#       4 # --- IGNORE ---
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1 = (1,8,9,4,5)
new_t1 = sorted(t1)

# %%
new_t1
print(type(new_t1))
# Out:
# <class 'list'>

# %%
t2 = (2,0,4,0,3,56,8,744,9)
sorted(t2)
# Out:
# [0, 0, 2, 3, 4, 8, 9, 56, 744]
