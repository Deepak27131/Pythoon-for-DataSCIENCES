# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.tree import plot_tree

# %%
x , y = make_classification(n_samples=200,n_features=5, n_redundant=0, n_informative=5,n_clusters_per_class=1)

# %%
df = pd.DataFrame(x ,columns=['col1','col2','col3','col4','col5'])
df['target'] = y

# %%
df
# Out:
#         col1      col2      col3      col4      col5  target
# 0   2.851723  0.674176 -2.183135 -0.308485 -0.598086       1
# 1   0.011676 -0.505650 -1.277886 -0.936904  2.825155       1
# 2   3.581593 -0.891777 -0.559708 -0.463363 -2.118663       1
# 3   2.500893 -0.496716 -1.915552 -1.764704 -0.619979       1
# 4   2.329371 -1.943352  0.719859  2.841425  0.446429       0
# ..       ...       ...       ...       ...       ...     ...
# 95  0.101259 -1.949818 -0.555571 -1.917888  1.417469       1
# 96 -0.907729 -1.708666 -2.938070 -0.881083  3.747262       1
# 97  1.256867 -1.392645  0.460521  1.256109  0.570662       0
# 98  0.378090  0.093809 -1.008750 -1.619673  1.705625       1
# 99  0.636236  0.533059  0.291600 -1.842906  2.104751       1
#
# [100 rows x 6 columns]

# %%
bag = BaggingClassifier(max_features=2)

# %%
bag.fit(df.iloc[:,:5],df.iloc[:,-1])
# Out:
# BaggingClassifier(max_features=2)

# %%
bag.fit(x,y)
# Out:
# BaggingClassifier(max_features=2)

# %%
plt.figure(figsize=(10,10))
plot_tree(bag.estimators_[0])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
rf = RandomForestClassifier(max_features=2)

# %%
rf.fit(x,y)
# Out:
# RandomForestClassifier(max_features=2)

# %%
plt.figure(figsize=(10,10))
plot_tree(rf.estimators_[0])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
